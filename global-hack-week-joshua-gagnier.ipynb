# %% [markdown]
# <a href="https://www.kaggle.com/code/joshuagagnier/global-hack-week-joshua-gagnier?scriptVersionId=158355652" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
#  Hello, World!

# %%
print('This is my Global Hack Week Submission Document')
# Out:
# This is my Global Hack Week Submission Document
